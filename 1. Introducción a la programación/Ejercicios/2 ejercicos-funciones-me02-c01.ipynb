# %% [markdown]
# ---
#
# # Introducción a la Programación
#
# - Curso original: [Intro to Programming](https://www.kaggle.com/learn/intro-to-programming)
#
# | Id | Lección | URL Original | Traducción | Ejercicios |
# |----|---------------------------------------------|-----------------------------------------|-------------------------------------------------------------|----------------|
# | 1 | **Aritmética y Variables** | [Arithmetic and Variables](https://www.kaggle.com/code/alexisbcook/arithmetic-and-variables) | [Aritmética y Variables](https://www.kaggle.com/code/beta3logic/aritm-tica-y-variables-m01-c01) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicios-aritm-tica-y-variables-me01-c01) |
# | 2 | **Funciones** | [Functions](https://www.kaggle.com/code/alexisbcook/functions) | [Funciones](https://www.kaggle.com/code/beta3logic/funciones-m02-c01) | **--Este módulo--** |
# | 3 | **Tipos de datos** | [Data Types](https://www.kaggle.com/code/alexisbcook/data-types) | [Tipos de datos](https://www.kaggle.com/code/beta3logic/tipos-de-datos-m03-c01) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicios-tipos-de-datos-me03-c01) |
# | 4 | **Condiciones y Sentencias condicionales**| [Conditions and Conditional Statements](https://www.kaggle.com/code/alexisbcook/conditions-and-conditional-statements) | [Condiciones y Sentencias condicionales](https://www.kaggle.com/code/beta3logic/condiciones-y-sentencias-condicionales-m04-co1) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicios-condiciones-me04-co1) |
# | 5 | **Introducción a listas** | [Intro to Lists](https://www.kaggle.com/code/alexisbcook/intro-to-lists) | [Introducción a listas](https://www.kaggle.com/code/beta3logic/introducci-n-a-listas-m05-c01) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicio-introducci-n-a-listas-me05-c01) |
#
# - Instructora y autora original: [Alexis Cook](https://www.kaggle.com/alexisbcook)
#
# ---
#
# ## ***Nota importante:***
# Como esta es una traducción del contenido original, el certificado no será válido en Kaggle. Te recomiendo replicar el contenido de este notebook directamente en el [enlace original (Exercise)](https://www.kaggle.com/learn/intro-to-programming) para que puedas obtener tu certificado oficial sin problemas.

# %% [markdown]
# **Este notebook es un ejercicio del curso [Introducción a la Programación](https://www.kaggle.com/learn/intro-to-programming). Puedes consultar el tutorial en [este enlace (inglés)](https://www.kaggle.com/alexisbcook/functions).**
#
# ---

# %% [markdown]
# En el tutorial aprendiste sobre las funciones. En este ejercicio, ¡escribirás algunas propias!
#
# # Configuración del notebook
#
# Ejecuta la siguiente celda de código sin hacer cambios para configurar el notebook.

# %%
# Configurar el notebook
import math
from learntools.core import binder
binder.bind(globals())
from learntools.intro_to_programming.ex2 import *
print('Configuración completa.')
# Out:
# Configuración completa.

# %% [markdown]
# # Pregunta 1
#
# En la competencia [House Prices - Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview), necesitas usar información como la cantidad de dormitorios y baños para predecir el precio de una casa. Inspirado en esta competencia, escribirás tu propia función para hacerlo.
#
# En el siguiente bloque de código, crea una función `get_expected_cost()` que tenga dos argumentos:
# - `camas` – número de dormitorios
# - `banos` – número de baños
#
# La función debe devolver el costo esperado de una casa con ese número de dormitorios y baños. Supón que:
# - el costo esperado de una casa con 0 dormitorios y 0 baños es `80000`.
# - cada dormitorio agrega `30000` al costo esperado
# - cada baño agrega `10000` al costo esperado
#
# Por ejemplo:
# - una casa con 1 dormitorio y 1 baño tiene un costo esperado de `120000`, y
# - una casa con 2 dormitorios y 1 baño tiene un costo esperado de `150000`.
#
# ***Nota*** : Los nombres de las funciones deben ser siempre en ingles para que el sistema sea capaz de reconocer el acierto. Reemplaza el valor de `000` por tu respuesta.

# %%
# ACTIVIDAD Completa la función
def get_expected_cost(camas, banos):
    value = 000
    return value

# Check your answer 
q1.check()
# Out:
# Incorrect: Expected return value of `80000` given `camas=0`, `banos=0`, but got `0` instead.

# %%
# Descomenta para ver una pista
# q1.hint()

# Descomenta para ver la solución
# q1.solution()

# %% [markdown]
# # Pregunta 2
#
# Estás pensando en comprar una casa y quieres tener una idea de cuánto gastarás, basado en el número de dormitorios y baños. Estás tratando de decidir entre cuatro opciones diferentes:
# - Opción 1: casa con dos dormitorios y tres baños
# - Opción 2: casa con tres dormitorios y dos baños
# - Opción 3: casa con tres dormitorios y tres baños
# - Opción 4: casa con tres dormitorios y cuatro baños
#
# Usa la función `get_expected_cost()` que definiste en la pregunta 1 para asignar a `opcion_1`, `opcion_2`, `opcion_3` y `opcion_4` el costo esperado de cada opción. Reemplaza el valor de `000` por tu respuesta.

# %%
# TODO: Usa la función get_expected_cost para completar cada valor
option_one = 000
option_two = 000
option_three = 000
option_four = 000

print(option_one) 
print(option_two) 
print(option_three) 
print(option_four) 

# Verifica tu respuesta 
q2.check()
# Out:
# 0
# 0
# 0
# 0
# Incorrect: Incorrect value for `option_one`: `0`

# %%
# Descomenta para ver una pista
# q2.hint()

# Descomenta para ver la solución
# q2.solution()

# %% [markdown]
# # Pregunta 3
#
# Eres un decorador de interiores y te gustaría usar Python para agilizar parte de tu trabajo. En concreto, estás creando una herramienta que planeas usar para calcular el costo de pintar una habitación.
#
# Como primer paso, define una función `get_cost()` que reciba como entrada:
# - `metros2_paredes` = metros cuadrados totales de las paredes que se van a pintar
# - `metros2_techo` = metros cuadrados del techo que se van a pintar
# - `metros2_por_galon` = cantidad de metros cuadrados que se pueden cubrir con un galón de pintura
# - `costo_por_galon` = costo (en dólares) de un galón de pintura
#
# La función debe devolver el costo (en dólares) de aplicar **una sola capa de pintura** en todas las paredes y el techo. Supón que puedes comprar exactamente la cantidad de pintura que necesitas, por lo que puedes adquirir fracciones de galón (por ejemplo, si necesitas 7.523 galones, puedes comprar exactamente esa cantidad, en lugar de tener que comprar 8 galones y desperdiciar pintura). **No redondees el resultado.**
#
# ***Nota*** : Los nombres de las funciones deben ser siempre en ingles para que el sistema sea capaz de reconocer el acierto. Reemplaza el valor de `000` por tu respuesta.

# %%
# ACTIVIDAD: Termina de definir la función
def get_cost(metros2_paredes, metros2_techo, metros2_por_galon, costo_por_galon):
    costo = 000
    return costo

# Verifica tu respuesta
q3.check()
# Out:
# Incorrect: Expected return value of `21.599999999999998` given `metros2_paredes=432`, `metros2_techo=144`, `metros2_por_galon=400`, `costo_por_galon=15`, but got `0` instead.

# %%
# Descomenta para ver una pista
#q3.hint()

# Descomenta para ver la solución
#q3.solution()

# %% [markdown]
# # Pregunta 4
#
# Usa la función `get_cost()` que definiste en la Pregunta 3 para calcular el costo de aplicar una mano de pintura a una habitación con:
# - 432 pies cuadrados de paredes, y
# - 144 pies cuadrados de techo.
#
# Asume que un galón de pintura cubre 400 pies cuadrados y cuesta $15. Al igual que en la Pregunta 3, asume que puedes comprar galones parciales de pintura. No redondees tu respuesta.
#
# ***Nota*** : El nombre de la variable debe ser siempre en ingles para que el sistema sea capaz de reconocer el acierto. Reemplaza el valor de `000` por tu respuesta.

# %%
# ACTIVIDAD: Asigna la variable project_cost al costo del proyecto
project_cost = 000

# Verifica tu respuesta
q4.check()
# Out:
# Incorrect: Incorrect value for `project_cost`: `0`

# %%
# Descomenta para ver una pista
# q4.hint()

# Descomenta para ver la solución
# q4.solution()

# %% [markdown]
# # 🌶️ **Pregunta 5**
#
# Ahora supongamos que ya no puedes comprar fracciones de un galón. (Por ejemplo, si necesitas 4.3 galones para un proyecto, entonces tienes que comprar 5 galones de pintura).
#
# Con este nuevo escenario, crearás una nueva función `get_actual_cost` que utilice las mismas entradas y calcule el costo real de tu proyecto.
#
# Una función que necesitarás usar para esto es `math.ceil()`. A continuación, se muestra cómo se utiliza esta función en el siguiente bloque de código. Esta función toma un número como entrada y lo redondea **hacia arriba** al entero más cercano.
#
# Ejecuta el siguiente bloque de código para probar esta función por tu cuenta. Puedes cambiar el valor de `valor_prueba` y verificar que `math.ceil()` devuelva el número que esperas.
#
# ***Nota*** : Los nombres de las funciones deben ser siempre en ingles para que el sistema sea capaz de reconocer el acierto. Reemplaza el valor de `000` por tu respuesta.

# %%
valor_prueba = 2.17

valor_redondeado = math.ceil(valor_prueba)
print(valor_redondeado)
# Out:
# 3

# %% [markdown]
# Usa la siguiente celda de código para definir la función `get_actual_cost()`. Para hacerlo, necesitarás usar la función `math.ceil()`.
#
# Al responder esta pregunta, ten en cuenta que es completamente válido definir una función que haga uso de otra función. Por ejemplo, podemos definir una función `redondear_hacia_arriba_y_dividir_por_tres` que utiliza la función `math.ceil`:
#
# ```
# def redondear_hacia_arriba_y_dividir_por_tres(numero):
#     nuevo_valor = math.ceil(numero)
#     valor_final = nuevo_valor / 3
#     return valor_final
# ```

# %%
def get_actual_cost(metros2_paredes, metros2_techo, metros2_por_galon, costo_por_galon):
    costo = 000
    return costo

# Verifica tu respuesta
q5.check()
# Out:
# Incorrect: Expected return value of `30` given `metros2_paredes=432`, `metros2_techo=144`, `metros2_por_galon=400`, `costo_por_galon=15`, but got `0` instead.

# %%
# Descomenta para ver una pista
#q5.hint()

# Descomenta para ver la solución
#q5.solution()

# %% [markdown]
# Una vez que tu función haya sido verificada como correcta, ejecuta el siguiente bloque de código para calcular el costo actualizado de tu proyecto.

# %%
## Para observar el resultado por favor elimina el simbolo " # " de la siguiente línea

#get_actual_cost(432, 144, 400, 15)

# %% [markdown]
# Supongamos que estás trabajando con una habitación un poco más grande. Ejecuta el siguiente bloque de código para calcular el costo del proyecto.

# %%
## Para observar el resultado por favor elimina el simbolo " # " de la siguiente línea

#get_actual_cost(594, 288, 400, 15)

# %% [markdown]
# # Sigue adelante
#
# Continúa aprendiendo sobre **[tipos de datos](https://www.kaggle.com/alexisbcook/data-types)**.

# %% [markdown]
# ---
#
#
#
#
# *¿Tienes preguntas o comentarios? Visita el [foro de discusión (inglés)](https://www.kaggle.com/learn/intro-to-programming/discussion) del curso para charlar con otros estudiantes.*

# %% [markdown]
# ```
#   _  __    _    ____  ____ _     _____
#  | |/ /   / \  / ___|/ ___| |   | ____|
#  | ' /   / _ \| |  _| |  _| |   |  _|
#  | . \  / ___ \ |_| | |_| | |___| |___
#  |_|\_\/_/   \_\____|\____|_____|_____|
#
# ```
