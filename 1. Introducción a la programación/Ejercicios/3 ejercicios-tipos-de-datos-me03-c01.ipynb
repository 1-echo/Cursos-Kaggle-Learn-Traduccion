# %% [markdown]
# ---
#
# # Introducción a la Programación
#
# - Curso original: [Intro to Programming](https://www.kaggle.com/learn/intro-to-programming)
#
# | Id | Lección | URL Original | Traducción | Ejercicios |
# |----|---------------------------------------------|-----------------------------------------|-------------------------------------------------------------|----------------|
# | 1 | **Aritmética y Variables** | [Arithmetic and Variables](https://www.kaggle.com/code/alexisbcook/arithmetic-and-variables) | [Aritmética y Variables](https://www.kaggle.com/code/beta3logic/aritm-tica-y-variables-m01-c01) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicios-aritm-tica-y-variables-me01-c01) |
# | 2 | **Funciones** | [Functions](https://www.kaggle.com/code/alexisbcook/functions) | [Funciones](https://www.kaggle.com/code/beta3logic/funciones-m02-c01) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicos-funciones-me02-c01) |
# | 3 | **Tipos de datos** | [Data Types](https://www.kaggle.com/code/alexisbcook/data-types) | [Tipos de datos](https://www.kaggle.com/code/beta3logic/tipos-de-datos-m03-c01) | **--Este módulo--** |
# | 4 | **Condiciones y Sentencias condicionales**| [Conditions and Conditional Statements](https://www.kaggle.com/code/alexisbcook/conditions-and-conditional-statements) | [Condiciones y Sentencias condicionales](https://www.kaggle.com/code/beta3logic/condiciones-y-sentencias-condicionales-m04-co1) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicios-condiciones-me04-co1) |
# | 5 | **Introducción a listas** | [Intro to Lists](https://www.kaggle.com/code/alexisbcook/intro-to-lists) | [Introducción a listas](https://www.kaggle.com/code/beta3logic/introducci-n-a-listas-m05-c01) | [Ejercicios](https://www.kaggle.com/code/beta3logic/ejercicio-introducci-n-a-listas-me05-c01) |
#
# - Instructora y autora original: [Alexis Cook](https://www.kaggle.com/alexisbcook)
#
# ---
#
# ## ***Nota importante:***
# Como esta es una traducción del contenido original, el certificado no será válido en Kaggle. Te recomiendo replicar el contenido de este notebook directamente en el [enlace original (Exercise)](https://www.kaggle.com/learn/intro-to-programming) para que puedas obtener tu certificado oficial sin problemas.

# %% [markdown]
# **Este notebook es un ejercicio del curso [Introducción a la Programación](https://www.kaggle.com/learn/intro-to-programming). Puedes consultar el tutorial en [este enlace](https://www.kaggle.com/alexisbcook/data-types).**
#
# ---

# %% [markdown]
# En el tutorial, aprendiste sobre cuatro tipos de datos diferentes: flotantes, enteros, cadenas de texto y booleanos. En este ejercicio, experimentarás con ellos.
#
# # Configuración del notebook
#
# Ejecuta la siguiente celda de código sin realizar cambios para configurar tanto el notebook como el entorno.

# %%
# Configuracion del Ejercicio
from learntools.core import binder
binder.bind(globals())
from learntools.intro_to_programming.ex3 import *
print('Configuración Existosa')
# Out:
# Configuración Existosa

# %% [markdown]
# # Pregunta 1
#
# Ya has visto cómo convertir un número flotante en un entero usando la función `int`. Pruébalo tú mismo ejecutando la celda de código a continuación.

# %%
# Define un número flotante (decimal)
y = 1.
print(y)
print(type(y))

# Convierte el decimal a entero con la función int()
z = int(y)
print(z)
print(type(z))
# Out:
# 1.0
# <class 'float'>
# 1
# <class 'int'>

# %% [markdown]
# En este caso, el número flotante que estás usando no tiene dígitos después del punto decimal.
# - ¿Qué sucede cuando intentas convertir a entero un flotante con parte fraccionaria?
# - ¿Cómo cambia el resultado de la función `int` para números positivos y negativos?
#
# Usa la siguiente celda de código para investigar y responder estas preguntas. Siéntete libre de agregar o eliminar cualquier línea de código: ¡es tu espacio de trabajo!

# %%
# Elimina el símbolo '#' y ejecuta este código para comenzar

#print(int(1.2321))
#print(int(1.747))
#print(int(-3.94535))
#print(int(-2.19774))

# %% [markdown]
# Una vez que tengas una respuesta, ejecuta la celda de código a continuación para ver la solución. Ver la solución te dará crédito por haber respondido el ejercicio.

# %%
# Verifica tu respuesta (¡Ejecuta esta celda de código para recibir una puntuación!)
q1.check()
# Out:
# Correct:
#
# Negative floats are always rounded UP to the closest integer (for instance, both -1.1 and -1.9 are rounded up to -1). Positive floats are always rounded DOWN to the closest integer (for instance, 2.1 and 2.9 are rounded down to 2).

# %% [markdown]
# # Pregunta 2
#
# En el tutorial, aprendiste sobre los booleanos (que pueden tomar el valor `True` o `False`), además de enteros, flotantes y cadenas de texto. En esta pregunta, tu objetivo es determinar qué sucede cuando multiplicas un booleano por cualquiera de estos tipos de datos. En concreto:
#
# - ¿Qué ocurre cuando multiplicas un entero o un flotante por `True`? ¿Y cuando los multiplicas por `False`? ¿Cómo cambia el resultado si los números son positivos o negativos?
# - ¿Qué sucede cuando multiplicas una cadena de texto por `True`? ¿Y por `False`?
#
# Usa la siguiente celda de código para realizar tu investigación.

# %%
# Elimina el símbolo '#' y ejecuta este código para comenzar

#print(3 * True)
#print(-3.1 * True)
#print(type("abc" * False))
#print(len("abc" * False))

# %% [markdown]
# Una vez que tengas una respuesta, ejecuta la celda de código a continuación para ver la solución. Ver la solución te dará crédito por haber respondido el ejercicio.

# %%
# Verifica tu respuesta (¡Ejecuta esta celda de código para recibir una puntuación!)
q2.check()
# Out:
# Correct:
#
# When you multiple an integer or float by a boolean with value `True`, it just returns that same integer or float (and is equivalent to multiplying by 1).  If you multiply an integer or float by a boolean with value `False`, it always returns 0.  This is true for both positive and negative numbers.  If you multiply a string by a boolean with value `True`, it just returns that same string.  And if you multiply a string by a boolean with value `False`, it returns an empty string (or a string with length zero).

# %% [markdown]
# # Pregunta 3
#
# En esta pregunta, desarrollarás una función que estime el valor de una casa.
#
# Usa la siguiente celda de código para crear una función `get_expected_cost` que reciba como entrada tres variables:
# - `camas` – número de habitaciones (tipo de dato float)
# - `banos` – número de baños (tipo de dato float)
# - `tiene_sotano` – indica si la casa tiene o no sótano (tipo de dato booleano)
#
# La función debe devolver el costo esperado de una casa con esas características. Supón que:
# - el costo esperado de una casa con 0 habitaciones, 0 baños y sin sótano es 80000,
# - cada habitación agrega 30000 al costo esperado,
# - cada baño agrega 10000 al costo esperado, y
# - un sótano agrega 40000 al costo esperado.
#
# Por ejemplo:
# - una casa con 1 habitación, 1 baño y sin sótano tiene un costo esperado de 80000 + 30000 + 10000 = 120000. Este valor se calcula con `get_expected_cost(1, 1, False)`.
# - una casa con 2 habitaciones, 1 baño y con sótano tiene un costo esperado de 80000 + 2*30000 + 10000 + 40000 = 190000. Este valor se calcula con `get_expected_cost(2, 1, True)`.
#
# Recuerda que siempre puedes obtener una pista descomentando `q3.hint()` en la celda de código que sigue a continuación.
#
# **Nota**: Los nombres de las funciones deben ser siempre en inglés para que el sistema sea capaz de reconocer el acierto. Reemplaza el valor de 000 por tu respuesta.

# %%
# ACTIVIDAD: Completa la función
def get_expected_cost(camas, banos, tiene_sotano):
    value = 000
    return value

# Revisa tu respuesta
q3.check()
# Out:
# Incorrect: Expected return value of `120000` given `camas=1`, `banos=1`, `tiene_sotano=False`, but got `0` instead.

# %%
# Descomenta para ver una pista
#q3.hint()

# Descomenta para ver la solución
#q3.solution()

# %% [markdown]
# # Pregunta 4
#
# Continuando con nuestro estudio de la aritmética con booleanos. En esta pregunta, tu tarea es describir qué sucede cuando sumas valores booleanos.
#
# Usa la siguiente celda de código para realizar tu investigación. Siéntete libre de agregar o eliminar cualquier línea de código: ¡úsala como tu espacio de trabajo!

# %%
# Elimina el símbolo '#' y ejecuta este código para comenzar

#print(False + False)
#print(True + False)
#print(False + True)
#print(True + True)
#print(False + True + True + True)

# %% [markdown]
# Una vez que tengas una respuesta, ejecuta la celda de código a continuación para ver la solución. Ver la solución te dará crédito por haber respondido el ejercicio.

# %%
# Verifica tu respuesta (¡Ejecuta esta celda de código para recibir una puntuación!)
q4.check()
# Out:
# Correct:
#
# When you add booleans, adding `False` is equivalent to adding 0, and adding `True` is equivalent to adding 1.

# %% [markdown]
# # 🌶️ Pregunta 5
#
# Eres dueño de una tienda en línea donde vendes anillos con grabados personalizados. Ofreces anillos bañados en oro y anillos de oro macizo.
# - Los anillos bañados en oro tienen un costo base de \\$50, y cobras \\$7 por cada unidad grabada.
# - Los anillos de oro macizo tienen un costo base de \\$100, y cobras \\$10 por cada unidad grabada.
# - Los espacios y signos de puntuación cuentan como unidades grabadas.
#
# Escribe una función `cost_of_project()` que reciba dos argumentos:
# - `grabado` – una cadena de texto en Python con el contenido del grabado
# - `oro_macizo` – un booleano que indica si el anillo es de oro macizo
#
# La función debe devolver el costo del proyecto. Esta pregunta es bastante desafiante, y puede que necesites una pista.
#
# **Nota**: Los nombres de las funciones deben ser siempre en inglés para que el sistema sea capaz de reconocer el acierto. Reemplaza el valor de 000 por tu respuesta.

# %%
def cost_of_project(grabado, oro_macizo):
    cost = 000
    return cost

# Revisa tu respuesta
q5.check()
# Out:
# Incorrect: Expected return value of `240` given `grabado='Charlie+Denver'`, `oro_macizo=True`, but got `0` instead.

# %%
# Descomenta para ver una pista
#q5.hint()

# Descomenta para ver la solución
#q5.solution()

# %% [markdown]
# Ejecuta la siguiente celda de código para calcular el costo de grabar `Charlie+Denver` en un anillo de oro macizo.

# %%
## Para observar el resultado por favor elimina el simbolo " # " de las siguientes líneas

#projecto_uno = cost_of_project("Charlie+Denver", True)
#print(projecto_uno)

# %% [markdown]
# Usa la siguiente celda de código para calcular el costo de grabar `08/10/2000` en un anillo bañado en oro.

# %%
## Para observar el resultado por favor elimina el simbolo " # " de las siguientes líneas

#projecto_dos = cost_of_project("08/10/2000", False)
#print(projecto_dos)

# %% [markdown]
# # Continúa
#
# Continúa con la siguiente lección para **[aprender sobre condiciones y sentencias condicionales](https://www.kaggle.com/alexisbcook/conditions-and-conditional-statements)**.

# %% [markdown]
# ---
#
# ¿Tienes preguntas o comentarios? Visita el **[foro de discusión del curso (inglés)](https://www.kaggle.com/learn/intro-to-programming/discussion)** para conversar con otros estudiantes.

# %% [markdown]
# ```
#   _  __    _    ____  ____ _     _____
#  | |/ /   / \  / ___|/ ___| |   | ____|
#  | ' /   / _ \| |  _| |  _| |   |  _|
#  | . \  / ___ \ |_| | |_| | |___| |___
#  |_|\_\/_/   \_\____|\____|_____|_____|
#
# ```
